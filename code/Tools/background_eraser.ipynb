# %%
import rembg
from PIL import Image
import os
import cv2

# %%
def erase_background(file_adr):
    img = Image.open(file_adr)#准备修改的图片路径
    img_bg_remove = rembg.remove(img)# 
    # img_bg_remove = img_bg_remove.convert('RGB')
    #如果需要保存为jpg或者jpeg格式则需要使用此行代码，使用后背景为黑色
    img_bg_remove.save(file_adr)#修改后保存的图片路径

# %%
BUSBRA_adr = '../../Data/BreastUltrasound/BUSBRA/'
BUSBset_adr = '../../Data/BreastUltrasound/BUSBset/'
BUSI_adr = '../../Data/BreastUltrasound/BUSI/'
USG_adr = '../../Data/BreastUltrasound/USG/'
domain_adr =[BUSBRA_adr,BUSBset_adr,BUSI_adr,USG_adr]

# %%
for i in range(4):
    adr = domain_adr[i]
    train_adr = os.path.join(adr,'train','mask')
    test_adr = os.path.join(adr,'test','mask')
    files = []
    for file in os.listdir(train_adr):
        file_adr = os.path.join(train_adr,file)
        files.append(file_adr)
    for file in os.listdir(test_adr):
        file_adr = os.path.join(test_adr,file)
        files.append(file_adr)
    for j in range(len(files)):
        erase_background(files[j])
# Out:
# /root/miniconda3/lib/python3.8/site-packages/rembg/sessions/base.py:52: RuntimeWarning: invalid value encountered in divide
#   im_ary = im_ary / np.max(im_ary)

# %%
# erase_background(os.path.join(BUSI_adr,'test','mask','malignant (64)_mask.png'))

# %%
def gray_converter(file_adr):
    image = cv2.imread(file_adr)
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    cv2.imwrite(file_adr, gray_image)

# %%
image = Image.open(os.path.join(BUSBRA_adr,'test','mask','mask_0001-l.png'))
gray_image = image.convert('L')
gray_image.save('s.png')
# image = cv2.imread(os.path.join(BUSBRA_adr,'test','mask','mask_0001-l.png'))
# gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# cv2.imwrite('sdada.png', gray_image)
print(gray_image.mode)
print(image.mode)
# cv2.imwrite(file_adr, gray_image)
# Out:
# L
# RGBA

# %%
for i in range(4):
    adr = domain_adr[i]
    train_adr = os.path.join(adr,'train','mask')
    test_adr = os.path.join(adr,'test','mask')
    files = []
    for file in os.listdir(train_adr):
        file_adr = os.path.join(train_adr,file)
        files.append(file_adr)
    for file in os.listdir(test_adr):
        file_adr = os.path.join(test_adr,file)
        files.append(file_adr)
    for j in range(len(files)):
        gray_converter(files[j])
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
#      11     files.append(file_adr)
#      12 for j in range(len(files)):
# ---> 13     gray_converter(files[j])
#
# Input In [16], in gray_converter(file_adr)
#       1 def gray_converter(file_adr):
#       2     image = cv2.imread(file_adr)
# ----> 3     gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
#       4     cv2.imwrite(file_adr, gray_image)
#
# error: OpenCV(4.9.0) /io/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'
